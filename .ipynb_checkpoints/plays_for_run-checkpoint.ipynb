# %%
from pypokerengine.api.game import setup_config, start_poker
from pypokerengine.utils.card_utils import gen_cards
from pypokerengine.players import BasePokerPlayer
from baseline_players import RandomPlayer
from bots.honest_player import HonestPlayer
from bots.honest_modified_player import HonestModifiedPlayer
from bots.bot_denis_2 import BotDenisPlayer
from bots.bot1 import KoffaPlayer
from bots.bot_denis_4 import 
from bots.forl_condition_bot_2 import ConditionPlayer
from bots.botDenis import GloomCha
from bots.forl_condition_bot import HonestStatPlayer
from bots.fish_player import FishPlayer
from bots.fold_player import FoldPlayer
from bots.bot_denis_3 import BotDenis3Player
from copy import deepcopy
import scipy.stats as sps
import keras.backend as K
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from bots.RLbot import RLPokerPlayer

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
N_RANDOM_PLAYERS = 0

config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
# config.register_player(name="foldman", algorithm=FoldPlayer())
config.register_player(name="honest", algorithm=HonestPlayer(200))
config.register_player(name="honest_modified", algorithm=HonestModifiedPlayer(200))
config.register_player(name="fishman", algorithm=FishPlayer())
config.register_player(name="botDenis1", algorithm=GloomCha())
config.register_player(name="botDenis2", algorithm=BotDenisPlayer())
config.register_player(name="conditionPlayer", algorithm=ConditionPlayer())
config.register_player(name="koffa", algorithm=KoffaPlayer())
config.register_player(name="botDenis3", algorithm=BotDenis3Player())
config.register_player(name="random", algorithm=RandomPlayer())

for i in range(N_RANDOM_PLAYERS):
    config.register_player(name="random" + str(i), algorithm=RandomPlayer())

# %%
# %%time
from joblib import Parallel, delayed

def f(i,config):
    return start_poker(config, verbose=0)['players']

def get_all_results(config, n_games=1):
    players_stack_dict = {}
    for player_info in config.players_info:
        players_stack_dict[player_info['name']] = []
        
    with Parallel(n_jobs=4) as parallel:
#     for i in tqdm(range(n_games)):
        data = parallel(delayed(f)(i, config) for i in range(n_games))
    
    for i in tqdm(range(n_games)):
        for player_info in data[i]:
            players_stack_dict[player_info['name']].append(player_info['stack'])
            
    return pd.DataFrame(players_stack_dict)

res = get_all_results(config, n_games=30)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "<timed exec>", line 4, in f
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/api/game.py", line 14, in start_poker
#     result_message = dealer.start_game(config.max_round)
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py", line 42, in start_game
#     table = self.play_round(round_count, sb_amount, ante, table)
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py", line 51, in play_round
#     answer = self.__publish_messages(msgs)
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py", line 113, in __publish_messages
#     return self.message_handler.process_message(*msgs[-1])
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py", line 202, in process_message
#     return receiver.respond_to_ask(msg["message"])
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/players/base.py", line 48, in respond_to_ask
#     return self.declare_action(valid_actions, hole_card, round_state)
#   File "/Users/sergmiller/Documents/code/python/pokerbot/bots/bot_denis_3.py", line 30, in declare_action
#     community_card=gen_cards(community_card)
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py", line 12, in estimate_hole_card_win_rate
#     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py", line 12, in <listcomp>
#     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py", line 39, in _montecarlo_simulation
#     return 1 if my_score >= max(opponents_score) else 0
# ValueError: max() arg is an empty sequence
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sergmiller/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/_parallel_backends.py", line 359, in __call__
#     raise TransportableException(text, e_type)
# joblib.my_exceptions.TransportableException: TransportableException
# ___________________________________________________________________________
# ValueError                                         Sat Sep 23 23:04:39 2017
# PID: 76549             Python 3.6.1: /Users/sergmiller/anaconda3/bin/python
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py in __call__(self=<joblib.parallel.BatchedCalls object>)
#     126     def __init__(self, iterator_slice):
#     127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#         self.items = [(<function f>, (3, <pypokerengine.api.game.Config object>), {})]
#     132
#     133     def __len__(self):
#     134         return self._size
#     135
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0=<list_iterator object>)
#     126     def __init__(self, iterator_slice):
#     127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#         func = <function f>
#         args = (3, <pypokerengine.api.game.Config object>)
#         kwargs = {}
#     132
#     133     def __len__(self):
#     134         return self._size
#     135
#
# ...........................................................................
# /Users/sergmiller/Documents/code/python/pokerbot/<timed exec> in f(i=3, config=<pypokerengine.api.game.Config object>)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/api/game.py in start_poker(config=<pypokerengine.api.game.Config object>, verbose=0, full_summary=False)
#       9     dealer = Dealer(config.sb_amount, config.initial_stack, config.ante, config.summary_file)
#      10     dealer.set_verbose(verbose)
#      11     dealer.set_blind_structure(config.blind_structure)
#      12     for info in config.players_info:
#      13         dealer.register_player(info["name"], info["algorithm"])
# ---> 14     result_message = dealer.start_game(config.max_round)
#         result_message = undefined
#         dealer.start_game = <bound method Dealer.start_game of <pypokerengine.engine.dealer.Dealer object>>
#         config.max_round = 50
#      15     if full_summary:
#      16         return dealer.game_summarizer.get_summary()
#      17     else:
#      18         return _format_result(result_message)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in start_game(self=<pypokerengine.engine.dealer.Dealer object>, max_round=50)
#      37     ante, sb_amount = self.ante, self.small_blind_amount
#      38     for round_count in range(1, max_round+1):
#      39       ante, sb_amount = self.__update_forced_bet_amount(ante, sb_amount, round_count, self.blind_structure)
#      40       table = self.__exclude_short_of_money_players(table, ante, sb_amount)
#      41       if self.__is_game_finished(table): break
# ---> 42       table = self.play_round(round_count, sb_amount, ante, table)
#         table = <pypokerengine.engine.table.Table object>
#         self.play_round = <bound method Dealer.play_round of <pypokerengine.engine.dealer.Dealer object>>
#         round_count = 14
#         sb_amount = 15
#         ante = 0
#      43       table.shift_dealer_btn()
#      44     return self.__generate_game_result(max_round, table.seats)
#      45
#      46   def play_round(self, round_count, blind_amount, ante, table):
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in play_round(self=<pypokerengine.engine.dealer.Dealer object>, round_count=14, blind_amount=15, ante=0, table=<pypokerengine.engine.table.Table object>)
#      46   def play_round(self, round_count, blind_amount, ante, table):
#      47     state, msgs = RoundManager.start_new_round(round_count, blind_amount, ante, table)
#      48     while True:
#      49       self.__message_check(msgs, state["street"])
#      50       if state["street"] != Const.Street.FINISHED:  # continue the round
# ---> 51         answer = self.__publish_messages(msgs)
#         answer = ('fold', 0)
#         self.__publish_messages = undefined
#         msgs = [(-1, {'message': {'action': {'action': 'fold', 'amount': 0, 'player_uuid': 'zwpkmufbkmsrglundslhys'}, 'action_histories': {'action_histories': {'preflop': [...]}}, 'message_type': 'game_update_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 6, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}}, 'type': 'notification'}), ('vjwwbftggiggjlnvnbcdtm', {'message': {'action_histories': {'action_histories': {'preflop': [...]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {...}}]}, 'type': 'ask'})]
#      52         bot_info = None
#      53         if len(answer) == 3:
#      54             action, bet_amount, bot_info = answer
#      55         else:
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in __publish_messages(self=<pypokerengine.engine.dealer.Dealer object>, msgs=[(-1, {'message': {'action': {'action': 'fold', 'amount': 0, 'player_uuid': 'zwpkmufbkmsrglundslhys'}, 'action_histories': {'action_histories': {'preflop': [...]}}, 'message_type': 'game_update_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 6, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}}, 'type': 'notification'}), ('vjwwbftggiggjlnvnbcdtm', {'message': {'action_histories': {'action_histories': {'preflop': [...]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {...}}]}, 'type': 'ask'})])
#     108   def __publish_messages(self, msgs):
#     109     for address, msg in msgs[:-1]:
#     110       self.message_handler.process_message(address, msg)
#     111     self.message_summarizer.summarize_messages(msgs)
#     112     self.game_summarizer.summarize_messages(msgs)
# --> 113     return self.message_handler.process_message(*msgs[-1])
#         self.message_handler.process_message = <bound method MessageHandler.process_message of <pypokerengine.engine.dealer.MessageHandler object>>
#         msgs = [(-1, {'message': {'action': {'action': 'fold', 'amount': 0, 'player_uuid': 'zwpkmufbkmsrglundslhys'}, 'action_histories': {'action_histories': {'preflop': [...]}}, 'message_type': 'game_update_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 6, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}}, 'type': 'notification'}), ('vjwwbftggiggjlnvnbcdtm', {'message': {'action_histories': {'action_histories': {'preflop': [...]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {...}}]}, 'type': 'ask'})]
#     114
#     115   def __exclude_short_of_money_players(self, table, ante, sb_amount):
#     116     sb_pos, bb_pos = self.__steal_money_from_poor_player(table, ante, sb_amount)
#     117     self.__disable_no_money_player(table.seats.players)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in process_message(self=<pypokerengine.engine.dealer.MessageHandler object>, address='vjwwbftggiggjlnvnbcdtm', msg={'message': {'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]}, 'type': 'ask'})
#     197
#     198   def process_message(self, address, msg):
#     199     receivers = self.__fetch_receivers(address)
#     200     for receiver in receivers:
#     201       if msg["type"] == 'ask':
# --> 202         return receiver.respond_to_ask(msg["message"])
#         receiver.respond_to_ask = <bound method BasePokerPlayer.respond_to_ask of <bots.bot_denis_3.BotDenis3Player object>>
#         msg = {'message': {'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]}, 'type': 'ask'}
#     203       elif msg["type"] == 'notification':
#     204         receiver.receive_notification(msg["message"])
#     205       else:
#     206         raise ValueError("Received unexpected message which type is [%s]" % msg["type"])
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/players/base.py in respond_to_ask(self=<bots.bot_denis_3.BotDenis3Player object>, message={'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]})
#      43         self.uuid = uuid
#      44
#      45     def respond_to_ask(self, message):
#      46         """Called from Dealer when ask message received from RoundManager"""
#      47         valid_actions, hole_card, round_state = self.__parse_ask_message(message)
# ---> 48         return self.declare_action(valid_actions, hole_card, round_state)
#         self.declare_action = <bound method BotDenis3Player.declare_action of <bots.bot_denis_3.BotDenis3Player object>>
#         valid_actions = [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]
#         hole_card = ['H6', 'S7']
#         round_state = {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}
#      49
#      50     def receive_notification(self, message):
#      51         """Called from Dealer when notification received from RoundManager"""
#      52         msg_type = message["message_type"]
#
# ...........................................................................
# /Users/sergmiller/Documents/code/python/pokerbot/bots/bot_denis_3.py in declare_action(self=<bots.bot_denis_3.BotDenis3Player object>, valid_actions=[{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}], hole_card=['H6', 'S7'], round_state={'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...})
#      25
#      26         win_rate = estimate_hole_card_win_rate(
#      27             nb_simulation=NB_SIMULATION,
#      28             nb_player=self.nb_active,
#      29             hole_card=gen_cards(hole_card),
# ---> 30             community_card=gen_cards(community_card)
#         community_card = []
#      31         )
#      32
#      33         street = round_state["street"]
#      34         percent = 1.0 / self.nb_active
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in estimate_hole_card_win_rate(nb_simulation=1000, nb_player=1, hole_card=[<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>], community_card=[])
#       7 def gen_cards(cards_str):
#       8     return [Card.from_str(s) for s in cards_str]
#       9
#      10 def estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card=None):
#      11     if not community_card: community_card = []
# ---> 12     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#         win_count = undefined
#         nb_player = 1
#         hole_card = [<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>]
#         community_card = []
#         nb_simulation = 1000
#      13     return 1.0 * win_count / nb_simulation
#      14
#      15 def gen_deck(exclude_cards=None):
#      16     deck_ids = range(1, 53)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in <listcomp>(.0=<range_iterator object>)
#       7 def gen_cards(cards_str):
#       8     return [Card.from_str(s) for s in cards_str]
#       9
#      10 def estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card=None):
#      11     if not community_card: community_card = []
# ---> 12     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#         _ = 0
#      13     return 1.0 * win_count / nb_simulation
#      14
#      15 def gen_deck(exclude_cards=None):
#      16     deck_ids = range(1, 53)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in _montecarlo_simulation(nb_player=1, hole_card=[<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>], community_card=[<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>])
#      34     community_card = _fill_community_card(community_card, used_card=hole_card+community_card)
#      35     unused_cards = _pick_unused_card((nb_player-1)*2, hole_card + community_card)
#      36     opponents_hole = [unused_cards[2*i:2*i+2] for i in range(nb_player-1)]
#      37     opponents_score = [HandEvaluator.eval_hand(hole, community_card) for hole in opponents_hole]
#      38     my_score = HandEvaluator.eval_hand(hole_card, community_card)
# ---> 39     return 1 if my_score >= max(opponents_score) else 0
#         my_score = 30326
#         opponents_score = []
#      40
#      41 def _fill_community_card(base_cards, used_card):
#      42     need_num = 5 - len(base_cards)
#      43     return base_cards + _pick_unused_card(need_num, used_card)
#
# ValueError: max() arg is an empty sequence
# ___________________________________________________________________________
# """
#
# The above exception was the direct cause of the following exception:
#
# TransportableException                    Traceback (most recent call last)
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#
# /Users/sergmiller/anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     607         else:
# --> 608             raise self._value
#     609
#
# TransportableException: TransportableException
# ___________________________________________________________________________
# ValueError                                         Sat Sep 23 23:04:39 2017
# PID: 76549             Python 3.6.1: /Users/sergmiller/anaconda3/bin/python
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py in __call__(self=<joblib.parallel.BatchedCalls object>)
#     126     def __init__(self, iterator_slice):
#     127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#         self.items = [(<function f>, (3, <pypokerengine.api.game.Config object>), {})]
#     132
#     133     def __len__(self):
#     134         return self._size
#     135
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0=<list_iterator object>)
#     126     def __init__(self, iterator_slice):
#     127         self.items = list(iterator_slice)
#     128         self._size = len(self.items)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#         func = <function f>
#         args = (3, <pypokerengine.api.game.Config object>)
#         kwargs = {}
#     132
#     133     def __len__(self):
#     134         return self._size
#     135
#
# ...........................................................................
# /Users/sergmiller/Documents/code/python/pokerbot/<timed exec> in f(i=3, config=<pypokerengine.api.game.Config object>)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/api/game.py in start_poker(config=<pypokerengine.api.game.Config object>, verbose=0, full_summary=False)
#       9     dealer = Dealer(config.sb_amount, config.initial_stack, config.ante, config.summary_file)
#      10     dealer.set_verbose(verbose)
#      11     dealer.set_blind_structure(config.blind_structure)
#      12     for info in config.players_info:
#      13         dealer.register_player(info["name"], info["algorithm"])
# ---> 14     result_message = dealer.start_game(config.max_round)
#         result_message = undefined
#         dealer.start_game = <bound method Dealer.start_game of <pypokerengine.engine.dealer.Dealer object>>
#         config.max_round = 50
#      15     if full_summary:
#      16         return dealer.game_summarizer.get_summary()
#      17     else:
#      18         return _format_result(result_message)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in start_game(self=<pypokerengine.engine.dealer.Dealer object>, max_round=50)
#      37     ante, sb_amount = self.ante, self.small_blind_amount
#      38     for round_count in range(1, max_round+1):
#      39       ante, sb_amount = self.__update_forced_bet_amount(ante, sb_amount, round_count, self.blind_structure)
#      40       table = self.__exclude_short_of_money_players(table, ante, sb_amount)
#      41       if self.__is_game_finished(table): break
# ---> 42       table = self.play_round(round_count, sb_amount, ante, table)
#         table = <pypokerengine.engine.table.Table object>
#         self.play_round = <bound method Dealer.play_round of <pypokerengine.engine.dealer.Dealer object>>
#         round_count = 14
#         sb_amount = 15
#         ante = 0
#      43       table.shift_dealer_btn()
#      44     return self.__generate_game_result(max_round, table.seats)
#      45
#      46   def play_round(self, round_count, blind_amount, ante, table):
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in play_round(self=<pypokerengine.engine.dealer.Dealer object>, round_count=14, blind_amount=15, ante=0, table=<pypokerengine.engine.table.Table object>)
#      46   def play_round(self, round_count, blind_amount, ante, table):
#      47     state, msgs = RoundManager.start_new_round(round_count, blind_amount, ante, table)
#      48     while True:
#      49       self.__message_check(msgs, state["street"])
#      50       if state["street"] != Const.Street.FINISHED:  # continue the round
# ---> 51         answer = self.__publish_messages(msgs)
#         answer = ('fold', 0)
#         self.__publish_messages = undefined
#         msgs = [(-1, {'message': {'action': {'action': 'fold', 'amount': 0, 'player_uuid': 'zwpkmufbkmsrglundslhys'}, 'action_histories': {'action_histories': {'preflop': [...]}}, 'message_type': 'game_update_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 6, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}}, 'type': 'notification'}), ('vjwwbftggiggjlnvnbcdtm', {'message': {'action_histories': {'action_histories': {'preflop': [...]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {...}}]}, 'type': 'ask'})]
#      52         bot_info = None
#      53         if len(answer) == 3:
#      54             action, bet_amount, bot_info = answer
#      55         else:
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in __publish_messages(self=<pypokerengine.engine.dealer.Dealer object>, msgs=[(-1, {'message': {'action': {'action': 'fold', 'amount': 0, 'player_uuid': 'zwpkmufbkmsrglundslhys'}, 'action_histories': {'action_histories': {'preflop': [...]}}, 'message_type': 'game_update_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 6, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}}, 'type': 'notification'}), ('vjwwbftggiggjlnvnbcdtm', {'message': {'action_histories': {'action_histories': {'preflop': [...]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {...}}]}, 'type': 'ask'})])
#     108   def __publish_messages(self, msgs):
#     109     for address, msg in msgs[:-1]:
#     110       self.message_handler.process_message(address, msg)
#     111     self.message_summarizer.summarize_messages(msgs)
#     112     self.game_summarizer.summarize_messages(msgs)
# --> 113     return self.message_handler.process_message(*msgs[-1])
#         self.message_handler.process_message = <bound method MessageHandler.process_message of <pypokerengine.engine.dealer.MessageHandler object>>
#         msgs = [(-1, {'message': {'action': {'action': 'fold', 'amount': 0, 'player_uuid': 'zwpkmufbkmsrglundslhys'}, 'action_histories': {'action_histories': {'preflop': [...]}}, 'message_type': 'game_update_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 6, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}}, 'type': 'notification'}), ('vjwwbftggiggjlnvnbcdtm', {'message': {'action_histories': {'action_histories': {'preflop': [...]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [...]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {...}, 'side': []}, 'round_count': 14, 'seats': [{...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {...}}]}, 'type': 'ask'})]
#     114
#     115   def __exclude_short_of_money_players(self, table, ante, sb_amount):
#     116     sb_pos, bb_pos = self.__steal_money_from_poor_player(table, ante, sb_amount)
#     117     self.__disable_no_money_player(table.seats.players)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in process_message(self=<pypokerengine.engine.dealer.MessageHandler object>, address='vjwwbftggiggjlnvnbcdtm', msg={'message': {'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]}, 'type': 'ask'})
#     197
#     198   def process_message(self, address, msg):
#     199     receivers = self.__fetch_receivers(address)
#     200     for receiver in receivers:
#     201       if msg["type"] == 'ask':
# --> 202         return receiver.respond_to_ask(msg["message"])
#         receiver.respond_to_ask = <bound method BasePokerPlayer.respond_to_ask of <bots.bot_denis_3.BotDenis3Player object>>
#         msg = {'message': {'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]}, 'type': 'ask'}
#     203       elif msg["type"] == 'notification':
#     204         receiver.receive_notification(msg["message"])
#     205       else:
#     206         raise ValueError("Received unexpected message which type is [%s]" % msg["type"])
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/players/base.py in respond_to_ask(self=<bots.bot_denis_3.BotDenis3Player object>, message={'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]})
#      43         self.uuid = uuid
#      44
#      45     def respond_to_ask(self, message):
#      46         """Called from Dealer when ask message received from RoundManager"""
#      47         valid_actions, hole_card, round_state = self.__parse_ask_message(message)
# ---> 48         return self.declare_action(valid_actions, hole_card, round_state)
#         self.declare_action = <bound method BotDenis3Player.declare_action of <bots.bot_denis_3.BotDenis3Player object>>
#         valid_actions = [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]
#         hole_card = ['H6', 'S7']
# ...
#     116     sb_pos, bb_pos = self.__steal_money_from_poor_player(table, ante, sb_amount)
#     117     self.__disable_no_money_player(table.seats.players)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in process_message(self=<pypokerengine.engine.dealer.MessageHandler object>, address='vjwwbftggiggjlnvnbcdtm', msg={'message': {'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]}, 'type': 'ask'})
#     197
#     198   def process_message(self, address, msg):
#     199     receivers = self.__fetch_receivers(address)
#     200     for receiver in receivers:
#     201       if msg["type"] == 'ask':
# --> 202         return receiver.respond_to_ask(msg["message"])
#         receiver.respond_to_ask = <bound method BasePokerPlayer.respond_to_ask of <bots.bot_denis_3.BotDenis3Player object>>
#         msg = {'message': {'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]}, 'type': 'ask'}
#     203       elif msg["type"] == 'notification':
#     204         receiver.receive_notification(msg["message"])
#     205       else:
#     206         raise ValueError("Received unexpected message which type is [%s]" % msg["type"])
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/players/base.py in respond_to_ask(self=<bots.bot_denis_3.BotDenis3Player object>, message={'action_histories': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}}, 'hole_card': ['H6', 'S7'], 'message_type': 'ask_message', 'round_state': {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}, 'valid_actions': [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]})
#      43         self.uuid = uuid
#      44
#      45     def respond_to_ask(self, message):
#      46         """Called from Dealer when ask message received from RoundManager"""
#      47         valid_actions, hole_card, round_state = self.__parse_ask_message(message)
# ---> 48         return self.declare_action(valid_actions, hole_card, round_state)
#         self.declare_action = <bound method BotDenis3Player.declare_action of <bots.bot_denis_3.BotDenis3Player object>>
#         valid_actions = [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}]
#         hole_card = ['H6', 'S7']
#         round_state = {'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...}
#      49
#      50     def receive_notification(self, message):
#      51         """Called from Dealer when notification received from RoundManager"""
#      52         msg_type = message["message_type"]
#
# ...........................................................................
# /Users/sergmiller/Documents/code/python/pokerbot/bots/bot_denis_3.py in declare_action(self=<bots.bot_denis_3.BotDenis3Player object>, valid_actions=[{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 348}, {'action': 'raise', 'amount': {'max': 7466, 'min': 666}}], hole_card=['H6', 'S7'], round_state={'action_histories': {'preflop': [{'action': 'SMALLBLIND', 'add_amount': 15, 'amount': 15, 'uuid': 'zwpkmufbkmsrglundslhys'}, {'action': 'BIGBLIND', 'add_amount': 15, 'amount': 30, 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'action': 'RAISE', 'add_amount': 318, 'amount': 348, 'paid': 348, 'uuid': 'yismvrkwvtwognclmhiqva'}, {'action': 'FOLD', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'action': 'FOLD', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'action': 'FOLD', 'uuid': 'zwpkmufbkmsrglundslhys'}]}, 'big_blind_pos': 7, 'community_card': [], 'dealer_btn': 4, 'next_player': 7, 'pot': {'main': {'amount': 393}, 'side': []}, 'round_count': 14, 'seats': [{'name': 'honest', 'stack': 0, 'state': 'folded', 'uuid': 'jlhhhbnmzqjtdgwhasxljs'}, {'name': 'honest_modified', 'stack': 2962, 'state': 'folded', 'uuid': 'pimktigefhxydmnrtoifpt'}, {'name': 'fishman', 'stack': 0, 'state': 'folded', 'uuid': 'feisymxitljaaxxkgrtdwh'}, {'name': 'botDenis1', 'stack': 0, 'state': 'folded', 'uuid': 'nymquixoazlzayokfflnbz'}, {'name': 'botDenis2', 'stack': 1365, 'state': 'folded', 'uuid': 'kxujkdsruiqzsqiaanltnk'}, {'name': 'conditionPlayer', 'stack': 0, 'state': 'folded', 'uuid': 'jluogdqynwxohgqevpxlgs'}, {'name': 'koffa', 'stack': 1320, 'state': 'folded', 'uuid': 'zwpkmufbkmsrglundslhys'}, {'name': 'botDenis3', 'stack': 7436, 'state': 'participating', 'uuid': 'vjwwbftggiggjlnvnbcdtm'}, {'name': 'random', 'stack': 23, 'state': 'participating', 'uuid': 'yismvrkwvtwognclmhiqva'}], 'small_blind_amount': 15, 'small_blind_pos': 6, ...})
#      25
#      26         win_rate = estimate_hole_card_win_rate(
#      27             nb_simulation=NB_SIMULATION,
#      28             nb_player=self.nb_active,
#      29             hole_card=gen_cards(hole_card),
# ---> 30             community_card=gen_cards(community_card)
#         community_card = []
#      31         )
#      32
#      33         street = round_state["street"]
#      34         percent = 1.0 / self.nb_active
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in estimate_hole_card_win_rate(nb_simulation=1000, nb_player=1, hole_card=[<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>], community_card=[])
#       7 def gen_cards(cards_str):
#       8     return [Card.from_str(s) for s in cards_str]
#       9
#      10 def estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card=None):
#      11     if not community_card: community_card = []
# ---> 12     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#         win_count = undefined
#         nb_player = 1
#         hole_card = [<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>]
#         community_card = []
#         nb_simulation = 1000
#      13     return 1.0 * win_count / nb_simulation
#      14
#      15 def gen_deck(exclude_cards=None):
#      16     deck_ids = range(1, 53)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in <listcomp>(.0=<range_iterator object>)
#       7 def gen_cards(cards_str):
#       8     return [Card.from_str(s) for s in cards_str]
#       9
#      10 def estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card=None):
#      11     if not community_card: community_card = []
# ---> 12     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#         _ = 0
#      13     return 1.0 * win_count / nb_simulation
#      14
#      15 def gen_deck(exclude_cards=None):
#      16     deck_ids = range(1, 53)
#
# ...........................................................................
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in _montecarlo_simulation(nb_player=1, hole_card=[<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>], community_card=[<pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>, <pypokerengine.engine.card.Card object>])
#      34     community_card = _fill_community_card(community_card, used_card=hole_card+community_card)
#      35     unused_cards = _pick_unused_card((nb_player-1)*2, hole_card + community_card)
#      36     opponents_hole = [unused_cards[2*i:2*i+2] for i in range(nb_player-1)]
#      37     opponents_score = [HandEvaluator.eval_hand(hole, community_card) for hole in opponents_hole]
#      38     my_score = HandEvaluator.eval_hand(hole_card, community_card)
# ---> 39     return 1 if my_score >= max(opponents_score) else 0
#         my_score = 30326
#         opponents_score = []
#      40
#      41 def _fill_community_card(base_cards, used_card):
#      42     need_num = 5 - len(base_cards)
#      43     return base_cards + _pick_unused_card(need_num, used_card)
#
# ValueError: max() arg is an empty sequence
# ___________________________________________________________________________

# %%
res.describe()
# Out:
#          botDenis1     botDenis2  conditionPlayer       fishman      foldman  \
# count    30.000000     30.000000        30.000000     30.000000    30.000000
# mean   2220.100000   3265.233333      1037.366667   1587.183333  1226.500000
# std    2342.734967   3374.607182      1933.654562   3000.216717   111.395149
# min       0.000000      0.000000         0.000000      0.000000   825.000000
# 25%    1143.750000      0.000000         0.000000      0.000000  1185.000000
# 50%    1342.500000   2507.500000         0.000000      0.000000  1230.000000
# 75%    2775.000000   5761.500000       714.000000   1648.125000  1286.250000
# max    9055.000000  10391.000000      5865.000000  11336.400000  1455.000000
#
#             honest  honest_modified       koffa       random
# count    30.000000        30.000000    30.00000    30.000000
# mean    879.976667      1285.400000  1510.60000   480.833333
# std    1758.441862       924.871794   352.56375  1359.559794
# min       0.000000         0.000000  1035.00000     0.000000
# 25%       0.000000       213.750000  1165.87500     0.000000
# 50%       0.000000      1443.500000  1502.10000     0.000000
# 75%    1032.375000      1771.250000  1781.25000     0.000000
# max    6985.000000      3105.000000  2364.30000  5250.000000

# %%
cnt = 0
class PrintPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"
    stats = PlayerStats()
    cnt = 0
    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]
        self.stats.update(hole_card, round_state)
        print(self.stats.calc_params(hole_card, round_state))
        call_action_info = valid_actions[1]
        action, amount = call_action_info["action"], call_action_info["amount"]
        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        self.stats.init_player_names(game_info)
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %%
res.describe()
# Out:
#             fishman      foldman        honest     random0       random1  \
# count     30.000000    30.000000     30.000000   30.000000     30.000000
# mean    4158.633333   887.000000   2133.866667   24.433333   1032.233333
# std     5569.237944   106.338756   3427.695272  133.826878   3305.520614
# min        0.000000   555.000000      0.000000    0.000000      0.000000
# 25%        0.000000   825.000000      0.000000    0.000000      0.000000
# 50%        0.000000   862.500000   1155.000000    0.000000      0.000000
# 75%    11102.750000   960.000000   1682.000000    0.000000      0.000000
# max    12902.000000  1110.000000  12523.000000  733.000000  12621.000000
#
#             random2       random3       random4       random5
# count     30.000000     30.000000     30.000000     30.000000
# mean    1666.566667   1490.666667   1260.933333    805.866667
# std     4321.575652   3961.730529   3847.468240   2675.882474
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000
# max    12542.000000  12590.000000  12616.000000  12634.000000

# %%
N = 100

RLBotPark = []
DefaultBotPark = [RandomPlayer(), HonestPlayer(), FishPlayer(), 
           BotDenisPlayer(), HonestModifiedPlayer(), ConditionPlayer(), 
           GloomCha(), KoffaPlayer(), HonestStatPlayer(),
          ]

rl_score = []


for i in range(N):
    in_model_file = None if i == 0 else 'model_{}.h5'.format(i)
    out_model_file = 'model_{}.h5'.format(i + 1)
    config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
    humans = list(np.random.choice(DefaultBotPark, replace=True, size=4 + max(0, 4 - len(RLBotPark))))
    rlbots = list(np.random.choice(RLBotPark, replace=True, size=min(4, len(RLBotPark)))) if len(RLBotPark) > 0 else []
    print(humans, rlbots)
    players = humans + rlbots + [None]
    np.random.shuffle(players)
    print(players)
    for player in players:
        if player is None:
            RLP =  RLPokerPlayer(
                study_mode=True,
                model_file=in_model_file,
                gammaReward=0.1,
                alphaUpdateNet=0.1,
                epsilonRandom=0.05,
                players=players,
                max_history_len=1000,
                new_model_file=out_model_file,
            )
            config.register_player(name='RL',algorithm=RLP)    
        else:
            config.register_player(name=str(player), algorithm=player)
    info = start_poker(config, verbose=0)
    RLP.study_mode = False
    for player_info in info:
        if player_info['name'] == 'RL':
            stack = player_info['stack']
            rl_score.append(stack)
            print(stack)
            break
# Out:
# [<bots.bot_denis_2.BotDenisPlayer object at 0x110d68208>, <bots.botDenis.GloomCha object at 0x126610c50>, <bots.bot1.KoffaPlayer object at 0x126610c88>, <bots.forl_condition_bot.HonestStatPlayer object at 0x125d437f0>, <bots.forl_condition_bot_2.ConditionPlayer object at 0x110d5ef28>, <bots.forl_condition_bot.HonestStatPlayer object at 0x125d437f0>, <bots.fish_player.FishPlayer object at 0x110d68780>, <bots.bot_denis_2.BotDenisPlayer object at 0x110d68208>] []
# [<bots.forl_condition_bot_2.ConditionPlayer object at 0x110d5ef28>, <bots.fish_player.FishPlayer object at 0x110d68780>, <bots.botDenis.GloomCha object at 0x126610c50>, <bots.bot_denis_2.BotDenisPlayer object at 0x110d68208>, <bots.bot_denis_2.BotDenisPlayer object at 0x110d68208>, <bots.bot1.KoffaPlayer object at 0x126610c88>, None, <bots.forl_condition_bot.HonestStatPlayer object at 0x125d437f0>, <bots.forl_condition_bot.HonestStatPlayer object at 0x125d437f0>]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-e5f9b45f8546> in <module>()
#      30                 players=players,
#      31                 max_history_len=1000,
# ---> 32                 new_model_file=out_model_file,
#      33             )
#      34             config.register_player(name='RL',algorithm=RLP)
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/RLbot.py in __init__(self, study_mode, model_file, new_model_file, gammaReward, alphaUpdateNet, epsilonRandom, players, max_history_len)
#      53             self.model = load_model(model_file)
#      54         else:
# ---> 55             self.model = commons.model1()
#      56
#      57
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/commons.py in model1(input_shape)
#     212              )
#     213     model.compile(loss=mean_squared_error,
# --> 214                   optimizer=sgd,
#     215                  )
#     216     return model
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/keras/models.py in compile(self, optimizer, loss, metrics, sample_weight_mode, **kwargs)
#     779                            metrics=metrics,
#     780                            sample_weight_mode=sample_weight_mode,
# --> 781                            **kwargs)
#     782         self.optimizer = self.model.optimizer
#     783         self.loss = self.model.loss
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, **kwargs)
#     838             loss_weight = loss_weights_list[i]
#     839             output_loss = weighted_loss(y_true, y_pred,
# --> 840                                         sample_weight, mask)
#     841             if len(self.outputs) > 1:
#     842                 self.metrics_tensors.append(output_loss)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in weighted(y_true, y_pred, weights, mask)
#     444         """
#     445         # score_array has ndim >= 2
# --> 446         score_array = fn(y_true, y_pred)
#     447         if mask is not None:
#     448             # Cast the mask to floatX to avoid float64 upcasting in theano
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     229     """
#     230     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 231         y_true, y_pred, multioutput)
#     232     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     233                                weights=sample_weight)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73     """
#      74     check_consistent_length(y_true, y_pred)
# ---> 75     y_true = check_array(y_true, ensure_2d=False)
#      76     y_pred = check_array(y_pred, ensure_2d=False)
#      77
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     400         # make sure we actually converted to numeric:
#     401         if dtype_numeric and array.dtype.kind == "O":
# --> 402             array = array.astype(np.float64)
#     403         if not allow_nd and array.ndim >= 3:
#     404             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: setting an array element with a sequence.

# %%
[1,2] + []
# Out:
# [1, 2]

# %%
str(HonestPlayer())
# Out:
# '<bots.honest_player.HonestPlayer object at 0x11c2326d8>'
