# %%
from pypokerengine.api.game import setup_config, start_poker
from pypokerengine.utils.card_utils import gen_cards
from pypokerengine.players import BasePokerPlayer
from baseline_players import RandomPlayer
from bots.honest_player import HonestPlayer
from bots.honest_modified_player import HonestModifiedPlayer
from bots.bot_denis_2 import BotDenisPlayer
from bots.bot1 import KoffaPlayer
# from bots.bot_denis_4 import 
from bots.forl_condition_bot_2 import ConditionPlayer
from bots.botDenis import GloomCha
from bots.forl_condition_bot import HonestStatPlayer
from bots.fish_player import FishPlayer
from bots.fold_player import FoldPlayer
from bots.bot_denis_3 import BotDenis3Player
from copy import deepcopy
import scipy.stats as sps
import keras.backend as K
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bots.RLbot import RLPokerPlayer
from tqdm import tqdm
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# N_RANDOM_PLAYERS = 0

# config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
# # config.register_player(name="foldman", algorithm=FoldPlayer())
# config.register_player(name="honest", algorithm=HonestPlayer(200))
# config.register_player(name="honest_modified", algorithm=HonestModifiedPlayer(200))
# config.register_player(name="fishman", algorithm=FishPlayer())
# config.register_player(name="botDenis1", algorithm=GloomCha())
# config.register_player(name="botDenis2", algorithm=BotDenisPlayer())
# config.register_player(name="conditionPlayer", algorithm=ConditionPlayer())
# config.register_player(name="koffa", algorithm=KoffaPlayer())
# config.register_player(name="botDenis3", algorithm=BotDenis3Player())
# config.register_player(name="random", algorithm=RandomPlayer())

# for i in range(N_RANDOM_PLAYERS):
#     config.register_player(name="random" + str(i), algorithm=RandomPlayer())

# %%
# %%time
# from joblib import Parallel, delayed

# def f(i,config):
#     return start_poker(config, verbose=0)['players']

# def get_all_results(config, n_games=1):
#     players_stack_dict = {}
#     for player_info in config.players_info:
#         players_stack_dict[player_info['name']] = []
        
#     with Parallel(n_jobs=4) as parallel:
# #     for i in tqdm(range(n_games)):
#         data = parallel(delayed(f)(i, config) for i in range(n_games))
    
#     for i in tqdm(range(n_games)):
#         for player_info in data[i]:
#             players_stack_dict[player_info['name']].append(player_info['stack'])
            
#     return pd.DataFrame(players_stack_dict)

# res = get_all_results(config, n_games=30)

# %%
N = 100

RLBotPark = []
DefaultBotPark = [RandomPlayer(), HonestPlayer(), FishPlayer(), 
           BotDenisPlayer(), HonestModifiedPlayer(), ConditionPlayer(), 
           GloomCha(), KoffaPlayer(), HonestStatPlayer(),
          ]

rl_score = []


for i in range(N):
    in_model_file = None if i == 0 else 'model_{}.h5'.format(i)
    out_model_file = 'model_{}.h5'.format(i + 1)
    config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
    humans = list(np.random.choice(DefaultBotPark, replace=True, size=4 + max(0, 4 - len(RLBotPark))))
    rlbots = list(np.random.choice(RLBotPark, replace=True, size=min(4, len(RLBotPark)))) if len(RLBotPark) > 0 else []
#     print(humans, rlbots)
    players = humans + rlbots + [None]
    np.random.shuffle(players)
#     print(players)
    j = 0
    for player in players:
        j += 1
        if player is None:
            RLP =  RLPokerPlayer(
                study_mode=True,
                model_file=in_model_file,
                gammaReward=0.5,
                alphaUpdateNet=0.1,
                epsilonRandom=0.1,
                decayRandom=0.95,
                players=players,
                max_history_len=1000,
                new_model_file=out_model_file,
            )
            config.register_player(name='RL',algorithm=RLP)    
        else:
            config.register_player(name=str(player) + str(j), algorithm=player)
    info = start_poker(config, verbose=0)
    RLP.study_mode = False
    res = []
    for player_info in info['players']:
        res.append((player_info['name'], player_info['stack']))
    res = sorted(res, key=(lambda x:x[1]))
    print(i, res)
# Out:
# action call, amount 1500
# 9 [('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>1', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>2', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>3', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>4', 0), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>5', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>6', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>7', 0), ('RL', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>8', 13482)]
# action raise, amount 1500
# action raise, amount 6015
# action raise, amount 6090
# action raise, amount 6135
# action raise, amount 6150
# action raise, amount 8523
# action raise, amount 8598
# action raise, amount 8643
# action raise, amount 8688
# action raise, amount 8703
# action raise, amount 9127
# action raise, amount 9232
# action raise, amount 9277
# action raise, amount 9322
# action raise, amount 9337
# action raise, amount 9431
# action raise, amount 9476
# action raise, amount 9521
# action raise, amount 9566
# action raise, amount 9581
# action raise, amount 9645
# action raise, amount 9690
# action raise, amount 9735
# action raise, amount 9780
# action raise, amount 9825
# action raise, amount 9870
# action raise, amount 9915
# action raise, amount 9960
# action raise, amount 10125
# action raise, amount 10170
# action raise, amount 10215
# action raise, amount 10260
# action raise, amount 10305
# action raise, amount 11490
# action raise, amount 11505
# action raise, amount 11655
# action raise, amount 11700
# action raise, amount 11745
# action raise, amount 11790
# action raise, amount 11835
# action raise, amount 11880
# action raise, amount 11895
# action raise, amount 11940
# action raise, amount 11985
# 9 [('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>1', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>2', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>3', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>4', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>6', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>7', 0), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>8', 705), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>5', 765), ('RL', 12030)]
# action raise, amount 1500
# 9 [('<baseline_players.RandomPlayer object at 0x11ecd4e80>1', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>2', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>3', 0), ('RL', 0), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>5', 1275), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>6', 1494), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>9', 2251), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>7', 2535), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>8', 5933)]
# action raise, amount 1500
# action raise, amount 3105
# action raise, amount 3150
# action raise, amount 3195
# action raise, amount 3240
# action raise, amount 3255
# action raise, amount 4075
# action raise, amount 4616
# action raise, amount 4721
# action raise, amount 6191
# action raise, amount 4736
# action raise, amount 6146
# action raise, amount 6275
# action raise, amount 6430
# action raise, amount 60
# action raise, amount 6415
# action raise, amount 6580
# action raise, amount 6625
# action raise, amount 6670
# action raise, amount 6715
# action raise, amount 6760
# action raise, amount 6805
# action raise, amount 60
# action raise, amount 6790
# action raise, amount 6925
# action raise, amount 9790
# action raise, amount 9835
# action raise, amount 9880
# action raise, amount 9895
# action raise, amount 9955
# action raise, amount 10000
# action raise, amount 10045
# action raise, amount 10060
# action raise, amount 10105
# action raise, amount 10210
# action raise, amount 10255
# action raise, amount 10270
# action raise, amount 10330
# action raise, amount 10375
# action raise, amount 10420
# action raise, amount 10435
# action raise, amount 10570
# action raise, amount 10615
# action raise, amount 10660
# action raise, amount 10705
# action raise, amount 10750
# action raise, amount 10795
# 9 [('<baseline_players.RandomPlayer object at 0x11ecd4e80>2', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>3', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>5', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>6', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>7', 0), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>8', 800), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>4', 915), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>1', 930), ('RL', 10855)]
# action raise, amount 1500
# 9 [('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>1', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>3', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>4', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>8', 0), ('RL', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>7', 60), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>6', 1035), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>5', 1140), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>2', 11265)]
# action raise, amount 1500
# action raise, amount 3015
# action raise, amount 1530
# action raise, amount 1575
# action raise, amount 60
# action raise, amount 15
# 9 [('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>1', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>3', 0), ('RL', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>5', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>9', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>2', 1305), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>8', 1680), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>7', 3225), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>6', 7275)]
# action raise, amount 1500
# action raise, amount 6030
# action raise, amount 4500
# action raise, amount 5149
# action raise, amount 3664
# action raise, amount 4488
# action raise, amount 4611
# action raise, amount 1611
# action raise, amount 1656
# action raise, amount 1701
# action raise, amount 1746
# action raise, amount 895
# action raise, amount 1836
# action raise, amount 1881
# action raise, amount 1926
# action raise, amount 1971
# action raise, amount 2016
# action raise, amount 651
# action raise, amount 696
# 9 [('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>1', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>2', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>4', 0), ('RL', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>9', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>3', 1290), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>7', 2244), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>8', 2640), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>5', 7317)]
# action raise, amount 1470
# action call, amount 1500
# 9 [('<baseline_players.RandomPlayer object at 0x11ecd4e80>1', 0), ('RL', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>4', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>5', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>6', 0), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>7', 0), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>2', 990), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>8', 1657), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>9', 10852)]
# action raise, amount 1500
# action raise, amount 9000
# action raise, amount 10500
# action raise, amount 10545
# action raise, amount 10590
# action raise, amount 10665
# action raise, amount 10710
# action raise, amount 10755
# action raise, amount 10800
# action raise, amount 10875
# action raise, amount 10920
# action raise, amount 10965
# action raise, amount 10980
# action raise, amount 11025
# action raise, amount 11100
# action raise, amount 11145
# action raise, amount 11190
# action raise, amount 11235
# action raise, amount 11280
# action raise, amount 11325
# action raise, amount 11370
# action raise, amount 11415
# action raise, amount 11460
# action raise, amount 11505
# action raise, amount 11580
# action raise, amount 11625
# action raise, amount 11670
# action raise, amount 11715
# action raise, amount 11760
# action raise, amount 11805
# action raise, amount 11880
# action raise, amount 11925
# action raise, amount 11970
# action raise, amount 12015
# action raise, amount 12060
# action raise, amount 12075
# 9 [('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>1', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>2', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>3', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>7', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>8', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>9', 0), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>4', 585), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>6', 780), ('RL', 12135)]
# action raise, amount 1500
# 9 [('RL', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>2', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>3', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>4', 0), ('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>5', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>6', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>7', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>9', 0), ('<bots.fish_player.FishPlayer object at 0x11ecd4ef0>8', 13500)]
# action raise, amount 1500
# 9 [('RL', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>2', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>3', 0), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>4', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>5', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>6', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>7', 495), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>9', 1489), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>8', 11498)]
# action raise, amount 1500
# action raise, amount 3803
# action raise, amount 3848
# action raise, amount 3893
# action raise, amount 60
# action raise, amount 2333
# action raise, amount 2707
# action call, amount 1207
# action raise, amount 4786
# action raise, amount 4831
# action raise, amount 3708
# action raise, amount 3753
# action raise, amount 3798
# action raise, amount 6089
# action raise, amount 6580
# action raise, amount 6625
# action raise, amount 6670
# action call, amount 30
# action raise, amount 6685
# action raise, amount 7018
# action raise, amount 4712
# action raise, amount 4757
# action raise, amount 4802
# action raise, amount 4847
# action raise, amount 9459
# action raise, amount 9504
# action raise, amount 9549
# action raise, amount 9594
# action raise, amount 8304
# action raise, amount 8349
# action raise, amount 8364
# action raise, amount 8424
# action raise, amount 8469
# action raise, amount 8514
# action raise, amount 8559
# action raise, amount 8604
# action raise, amount 8649
# action raise, amount 8694
# action raise, amount 8739
# action raise, amount 8784
# action raise, amount 8829
# action raise, amount 8904
# action raise, amount 8949
# action raise, amount 8994
# action raise, amount 9039
# action raise, amount 9084
# 9 [('<baseline_players.RandomPlayer object at 0x11ecd4e80>2', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>3', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>5', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>7', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>9', 0), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>6', 825), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>8', 1035), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>4', 2490), ('RL', 9129)]
# action raise, amount 1500
# 9 [('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>3', 0), ('RL', 0), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>8', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ece8080>5', 75), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>9', 1350), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>4', 1500), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ecd4f60>2', 2895), ('<bots.botDenis.GloomCha object at 0x11ecd4fd0>6', 2985), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>1', 4695)]
# action call, amount 1500
# 9 [('<bots.honest_player.HonestPlayer object at 0x11ecd4eb8>3', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>5', 0), ('RL', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ecd4f98>8', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>9', 0), ('<baseline_players.RandomPlayer object at 0x11ecd4e80>1', 659), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>2', 930), ('<bots.bot1.KoffaPlayer object at 0x11ece8048>4', 1290), ('<bots.bot_denis_2.BotDenisPlayer object at 0x11ecd4f28>6', 10590)]
# action raise, amount 1500
