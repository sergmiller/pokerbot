# %%
from pypokerengine.api.game import setup_config, start_poker
from pypokerengine.utils.card_utils import gen_cards
from pypokerengine.players import BasePokerPlayer
from baseline_players import RandomPlayer
from bots.honest_player import HonestPlayer
from bots.honest_modified_player import HonestModifiedPlayer
from bots.bot_denis_2 import BotDenisPlayer
from bots.bot1 import KoffaPlayer
from bots.bestbot import BestPlayer
# from bots.bot_denis_4 import 
from bots.forl_condition_bot_2 import ConditionPlayer
from bots.botDenis import GloomCha
from bots.forl_condition_bot import HonestStatPlayer
from bots.fish_player import FishPlayer
from bots.fold_player import FoldPlayer
from bots.bot_denis_3 import BotDenis3Player
from copy import deepcopy
import scipy.stats as sps
import keras.backend as K
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bots.RLbot import RLPokerPlayer
from tqdm import tqdm
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# N_RANDOM_PLAYERS = 0

# config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
# # config.register_player(name="foldman", algorithm=FoldPlayer())
# config.register_player(name="honest", algorithm=HonestPlayer(200))
# config.register_player(name="honest_modified", algorithm=HonestModifiedPlayer(200))
# config.register_player(name="fishman", algorithm=FishPlayer())
# config.register_player(name="botDenis1", algorithm=GloomCha())
# config.register_player(name="botDenis2", algorithm=BotDenisPlayer())
# config.register_player(name="conditionPlayer", algorithm=ConditionPlayer())
# config.register_player(name="koffa", algorithm=KoffaPlayer())
# config.register_player(name="botDenis3", algorithm=BotDenis3Player())
# config.register_player(name="random", algorithm=RandomPlayer())

# for i in range(N_RANDOM_PLAYERS):
#     config.register_player(name="random" + str(i), algorithm=RandomPlayer())

# %%
# %%time
# from joblib import Parallel, delayed

# def f(i,config):
#     return start_poker(config, verbose=0)['players']

# def get_all_results(config, n_games=1):
#     players_stack_dict = {}
#     for player_info in config.players_info:
#         players_stack_dict[player_info['name']] = []
        
#     with Parallel(n_jobs=4) as parallel:
# #     for i in tqdm(range(n_games)):
#         data = parallel(delayed(f)(i, config) for i in range(n_games))
    
#     for i in tqdm(range(n_games)):
#         for player_info in data[i]:
#             players_stack_dict[player_info['name']].append(player_info['stack'])
            
#     return pd.DataFrame(players_stack_dict)

# res = get_all_results(config, n_games=30)

# %%
N = 100

RLBotPark = []
DefaultBotPark = [RandomPlayer(), HonestPlayer(), FishPlayer(), 
           BotDenisPlayer(), HonestModifiedPlayer(), ConditionPlayer(), 
           GloomCha(), KoffaPlayer(), HonestStatPlayer(), BestPlayer(),
          ]

rl_score = []

mn = []


for i in range(N):
    in_model_file = None if i == 0 else 'model_{}.h5'.format(i)
    out_model_file = 'model_{}.h5'.format(i + 1)
    config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
    humans = list(np.random.choice(DefaultBotPark, replace=True, size=4 + max(0, 4 - len(RLBotPark))))
    rlbots = list(np.random.choice(RLBotPark, replace=True, size=min(4, len(RLBotPark)))) if len(RLBotPark) > 0 else []
#     print(humans, rlbots)
    players = humans + rlbots + [None]
    np.random.shuffle(players)
#     print(players)
    j = 0
    for player in players:
        j += 1
        if player is None:
            RLP =  RLPokerPlayer(
                study_mode=True,
                model_file=in_model_file,
                gammaReward=0.5,
                alphaUpdateNet=0.1,
                epsilonRandom=0.1,
                decayRandom=0.95,
                players=players,
                max_history_len=1000,
                new_model_file=out_model_file,
            )
            config.register_player(name='RL',algorithm=RLP)    
        else:
            config.register_player(name=str(player) + str(j), algorithm=player)
    info = start_poker(config, verbose=0)
    RLP.study_mode = False
    res = []
    for player_info in info['players']:
        res.append((player_info['name'], player_info['stack']))
    res = sorted(res, key=(lambda x:x[1]))
    print(i, res)
    for it in res:
        if it[0] == 'RL':
            mn.append(it[1])
            break
    print('mean res: {}'.format(mn.mean()))
#     RLP.study_mode=False
#     RLBotPark.append(
#     RLPokerPlayer(
#                 study_mode=False,
#                 model_file=in_model_file,
#                 gammaReward=0.5,
#                 alphaUpdateNet=0.1,
#                 epsilonRandom=0.1,
#                 decayRandom=0.95,
#                 players=players,
#                 max_history_len=1000,
#                 new_model_file=None,
#             )
#     )
# Out:
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 720
# action call, amount 0
# action call, amount 0
# action call, amount 30
# action raise, amount 345
# action call, amount 0
# action call, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# 0 [('<bots.fish_player.FishPlayer object at 0x11ee6e278>1', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>3', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>8', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>9', 0), ('RL', 75), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>2', 2027.5), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>5', 3330), ('<bots.botDenis.GloomCha object at 0x11ef1c240>6', 3776), ('<bots.botDenis.GloomCha object at 0x11ef1c240>4', 4290)]
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 45
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# 1 [('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>2', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>4', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>6', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>7', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>9', 0), ('RL', 495), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>3', 945), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>8', 1980), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>1', 10080)]
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action call, amount 30
# action call, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 0
# action call, amount 30
# action call, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 0
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# 2 [('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>2', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>3', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>4', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>5', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>8', 0), ('RL', 1095), ('<bots.botDenis.GloomCha object at 0x11ef1c240>6', 1215), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>1', 2580), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>9', 8610)]
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 45
# action raise, amount 30
# action raise, amount 30
# action call, amount 0
# action call, amount 45
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 45
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 45
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 1530
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 2028
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# 3 [('<baseline_players.RandomPlayer object at 0x11ee6ecc0>3', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>5', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>6', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>7', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>8', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>9', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>2', 630), ('RL', 2719), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>4', 10120)]
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 630
# 4 [('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>2', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>3', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>5', 0), ('RL', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>8', 0), ('<bots.botDenis.GloomCha object at 0x11ef1c240>6', 1185), ('<bots.botDenis.GloomCha object at 0x11ef1c240>9', 2040), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>4', 3390), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>1', 6885)]
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action raise, amount 690
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 375
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 15
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 15
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 15
# action call, amount 30
# action fold, amount 0
# 5 [('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>6', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>7', 0), ('RL', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>2', 480), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>3', 1290), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>4', 1875), ('<bots.botDenis.GloomCha object at 0x11ef1c240>8', 2535), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>5', 3285), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>1', 4005)]
# action call, amount 30
# action raise, amount 1011
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action raise, amount 315
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 24
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 21
# 6 [('<baseline_players.RandomPlayer object at 0x11ee6ecc0>2', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>3', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>4', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>5', 0), ('RL', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>8', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>1', 2462), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>7', 5280), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>9', 5732)]
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action raise, amount 367
# action raise, amount 390
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 24
# 7 [('<baseline_players.RandomPlayer object at 0x11ee6ecc0>2', 0), ('RL', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>9', 0), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>1', 1080), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>4', 1200), ('<bots.botDenis.GloomCha object at 0x11ef1c240>6', 1230), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>5', 1359), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>8', 1572), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>3', 7059)]
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 532
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 60
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# 8 [('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>1', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>2', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>4', 0), ('<bots.botDenis.GloomCha object at 0x11ef1c240>5', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>7', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>9', 0), ('RL', 878), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>3', 2940), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>8', 9664)]
# action call, amount 150
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 660
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 795
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action call, amount 60
# action call, amount 60
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action raise, amount 975
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# 9 [('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>2', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>3', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>6', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>7', 0), ('RL', 705), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>8', 780), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>1', 885), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>5', 1095), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>4', 10005)]
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action fold, amount 0
# action call, amount 30
# action call, amount 135
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 45
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 60
# 10 [('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>3', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>6', 0), ('RL', 0), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>5', 945), ('<bots.botDenis.GloomCha object at 0x11ef1c240>8', 1200), ('<bots.botDenis.GloomCha object at 0x11ef1c240>2', 1215), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>4', 1260), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>1', 1605), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>9', 7275)]
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 240
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action raise, amount 1005
# action raise, amount 30
# action call, amount 30
# action raise, amount 2355
# action raise, amount 30
# 11 [('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>1', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>2', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>3', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>4', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>6', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>7', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>8', 0), ('RL', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>5', 13500)]
# action raise, amount 60
# action raise, amount 720
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 75
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 105
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 72
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 681
# action call, amount 45
# action call, amount 30
# action fold, amount 0
# action call, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 60
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 90
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# 12 [('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>1', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>2', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>3', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>4', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>5', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>6', 0), ('RL', 2082), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>9', 3630), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>8', 7786)]
# action call, amount 30
# action raise, amount 802
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 668
# 13 [('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>4', 0), ('RL', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>6', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>9', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>8', 825), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>1', 836), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>7', 1305), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>3', 4129), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>2', 6405)]
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 105
# action call, amount 120
# action raise, amount 240
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 1177
# action raise, amount 30
# action raise, amount 30
# action raise, amount 574
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 1380
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 2850
# 14 [('RL', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>2', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>4', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>6', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>8', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>3', 1065), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>5', 2237), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>9', 2655), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>7', 7543)]
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 135
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action fold, amount 0
# action raise, amount 60
# action raise, amount 60
# action call, amount 30
# action call, amount 75
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action fold, amount 0
# action call, amount 120
# action raise, amount 30
# action call, amount 120
# action raise, amount 30
# action call, amount 120
# action raise, amount 225
# action raise, amount 60
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action fold, amount 0
# action raise, amount 60
# action raise, amount 60
# action raise, amount 60
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 75
# action call, amount 120
# action fold, amount 0
# action raise, amount 60
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 60
# action raise, amount 60
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 75
# action call, amount 120
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 75
# action call, amount 120
# action fold, amount 0
# action raise, amount 60
# action call, amount 60
# action call, amount 60
# action call, amount 60
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action fold, amount 0
# action call, amount 30
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 112
# 15 [('RL', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>4', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>7', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>8', 0), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>3', 600), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>5', 1380), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>9', 1755), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>2', 2085), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>6', 7655)]
# action raise, amount 60
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action call, amount 135
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 112
# action fold, amount 0
# action call, amount 30
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 105
# action call, amount 8
# 16 [('<baseline_players.RandomPlayer object at 0x11ee6ecc0>2', 0), ('<bots.botDenis.GloomCha object at 0x11ef1c240>3', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>4', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>6', 0), ('RL', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>8', 0), ('<bots.botDenis.GloomCha object at 0x11ef1c240>9', 0), ('<bots.fish_player.FishPlayer object at 0x11ee6e278>5', 5097), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>1', 8378)]
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 54
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 92
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 99
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 60
# action raise, amount 30
# action call, amount 120
# action call, amount 60
# action call, amount 60
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 0
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 60
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 1117
# 17 [('RL', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>4', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>5', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>6', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>7', 0), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>3', 1717), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>8', 2084.5), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>9', 4718), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>1', 4977)]
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 150
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 135
# action call, amount 120
# action call, amount 120
# action raise, amount 292
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 113
# action call, amount 30
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 135
# action call, amount 76
# action call, amount 30
# action call, amount 135
# action call, amount 120
# action call, amount 84
# action call, amount 30
# action call, amount 135
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 135
# action raise, amount 136
# 18 [('RL', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>2', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>3', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>4', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>9', 0), ('<bots.botDenis.GloomCha object at 0x11ef1c240>6', 1215), ('<bots.botDenis.GloomCha object at 0x11ef1c240>8', 1335), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>5', 2984), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>7', 7965)]
# action call, amount 30
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action call, amount 144
# action call, amount 34
# action raise, amount 32
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 60
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 60
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 60
# action raise, amount 30
# action raise, amount 60
# action call, amount 75
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 0
# action fold, amount 0
# action call, amount 60
# action raise, amount 30
# action raise, amount 60
# action raise, amount 60
# action call, amount 60
# action call, amount 60
# action call, amount 60
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 60
# action call, amount 30
# action call, amount 30
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 30
# action call, amount 120
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 49.5
# action call, amount 79.2
# action call, amount 60
# action raise, amount 60
# action call, amount 49.5
# action raise, amount 120
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 60
# action raise, amount 30
# action call, amount 120
# action call, amount 60
# action raise, amount 30
# action raise, amount 60
# ...
# action call, amount 120
# action raise, amount 60
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 74
# 23 [('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>1', 0), ('RL', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>5', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>8', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>9', 0), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>4', 540), ('<bots.botDenis.GloomCha object at 0x11ef1c240>7', 1170), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>6', 5538), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>2', 6252)]
# action call, amount 30
# action call, amount 210
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action fold, amount 0
# action call, amount 150
# action raise, amount 30
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action raise, amount 60
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action call, amount 150
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 90
# action call, amount 120
# action call, amount 120
# action call, amount 60
# 24 [('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>1', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>2', 0), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>5', 0), ('RL', 0), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>7', 1245), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>4', 1320), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>9', 2250), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>6', 2685), ('<bots.forl_condition_bot_2.ConditionPlayer object at 0x11ef1c208>3', 5970)]
# action fold, amount 0
# action fold, amount 0
# action fold, amount 0
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action raise, amount 60
# action call, amount 150
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 135
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 75
# action raise, amount 405
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 75
# action raise, amount 2445
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action fold, amount 0
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action call, amount 75
# action call, amount 120
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 75
# action fold, amount 0
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action call, amount 90
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action fold, amount 0
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 30
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 105
# action fold, amount 0
# action call, amount 105
# action fold, amount 0
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 90
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action call, amount 75
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 75
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action call, amount 90
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# 25 [('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>2', 0), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>3', 0), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>4', 0), ('<baseline_players.RandomPlayer object at 0x11ee6ecc0>7', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>9', 437), ('<bots.honest_player.HonestPlayer object at 0x11ee6eb70>8', 1799), ('<bots.botDenis.GloomCha object at 0x11ef1c240>5', 2520), ('RL', 3450), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>6', 5272)]
# action call, amount 60
# action call, amount 165
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action fold, amount 0
# action call, amount 30
# action call, amount 0
# action raise, amount 30
# action raise, amount 532
# action raise, amount 60
# action raise, amount 60
# action fold, amount 0
# action raise, amount 60
# action call, amount 135
# action fold, amount 0
# action fold, amount 0
# action raise, amount 60
# action call, amount 105
# action raise, amount 30
# action fold, amount 0
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action raise, amount 60
# action call, amount 60
# action raise, amount 30
# action raise, amount 60
# action call, amount 135
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action call, amount 30
# action call, amount 105
# action call, amount 120
# action call, amount 120
# action call, amount 120
# action raise, amount 60
# action call, amount 30
# action raise, amount 1177
# action raise, amount 90
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 60
# action call, amount 60
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 75
# action raise, amount 30
# action fold, amount 0
# action raise, amount 60
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 120
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 60
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action call, amount 75
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action fold, amount 0
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action call, amount 30
# action raise, amount 30
# action raise, amount 60
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# 26 [('<bots.fish_player.FishPlayer object at 0x11ee6e278>2', 0), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>3', 0), ('<bots.forl_condition_bot.HonestStatPlayer object at 0x11ef1c2b0>9', 0), ('<bots.bot1.KoffaPlayer object at 0x11ef1c278>1', 1050), ('<bots.bot_denis_2.BotDenisPlayer object at 0x108c8c9e8>4', 1095), ('<bots.botDenis.GloomCha object at 0x11ef1c240>8', 1230), ('<bots.bestbot.BestPlayer object at 0x11ef1c2e8>7', 2850), ('RL', 3000), ('<bots.honest_modified_player.HonestModifiedPlayer object at 0x11ef1c1d0>6', 4260)]
# action fold, amount 0
# action raise, amount 60
# action raise, amount 720
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# action call, amount 30
# action fold, amount 0
# action call, amount 30
# action raise, amount 30
# action raise, amount 30
# action raise, amount 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f01b840d3d90> in <module>()
#      38         else:
#      39             config.register_player(name=str(player) + str(j), algorithm=player)
# ---> 40     info = start_poker(config, verbose=0)
#      41     RLP.study_mode = False
#      42     res = []
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/api/game.py in start_poker(config, verbose, full_summary)
#      12     for info in config.players_info:
#      13         dealer.register_player(info["name"], info["algorithm"])
# ---> 14     result_message = dealer.start_game(config.max_round)
#      15     if full_summary:
#      16         return dealer.game_summarizer.get_summary()
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in start_game(self, max_round)
#      40       table = self.__exclude_short_of_money_players(table, ante, sb_amount)
#      41       if self.__is_game_finished(table): break
# ---> 42       table = self.play_round(round_count, sb_amount, ante, table)
#      43       table.shift_dealer_btn()
#      44     return self.__generate_game_result(max_round, table.seats)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in play_round(self, round_count, blind_amount, ante, table)
#      49       self.__message_check(msgs, state["street"])
#      50       if state["street"] != Const.Street.FINISHED:  # continue the round
# ---> 51         answer = self.__publish_messages(msgs)
#      52         bot_info = None
#      53         if len(answer) == 3:
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in __publish_messages(self, msgs)
#     111     self.message_summarizer.summarize_messages(msgs)
#     112     self.game_summarizer.summarize_messages(msgs)
# --> 113     return self.message_handler.process_message(*msgs[-1])
#     114
#     115   def __exclude_short_of_money_players(self, table, ante, sb_amount):
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in process_message(self, address, msg)
#     200     for receiver in receivers:
#     201       if msg["type"] == 'ask':
# --> 202         return receiver.respond_to_ask(msg["message"])
#     203       elif msg["type"] == 'notification':
#     204         receiver.receive_notification(msg["message"])
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/players/base.py in respond_to_ask(self, message)
#      46         """Called from Dealer when ask message received from RoundManager"""
#      47         valid_actions, hole_card, round_state = self.__parse_ask_message(message)
# ---> 48         return self.declare_action(valid_actions, hole_card, round_state)
#      49
#      50     def receive_notification(self, message):
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/RLbot.py in declare_action(self, valid_actions, hole_card, round_state)
#     136         self.stats.update(hole_card, round_state)
#     137
# --> 138         round_state_vec = self.stats.calc_fine_params(hole_card, round_state)
#     139
#     140         my_stack = round_state['seats'][self.my_seat]['stack']
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/commons.py in calc_fine_params(self, hole_card, round_states)
#     169                     nb_player=n_active_players,
#     170                     hole_card=gen_cards(hole_card),
# --> 171                     community_card=gen_cards(community_card)
#     172                 )
#     173         global_params.append(win_rate)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card)
#      10 def estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card=None):
#      11     if not community_card: community_card = []
# ---> 12     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#      13     return 1.0 * win_count / nb_simulation
#      14
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in <listcomp>(.0)
#      10 def estimate_hole_card_win_rate(nb_simulation, nb_player, hole_card, community_card=None):
#      11     if not community_card: community_card = []
# ---> 12     win_count = sum([_montecarlo_simulation(nb_player, hole_card, community_card) for _ in range(nb_simulation)])
#      13     return 1.0 * win_count / nb_simulation
#      14
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in _montecarlo_simulation(nb_player, hole_card, community_card)
#      33 def _montecarlo_simulation(nb_player, hole_card, community_card):
#      34     community_card = _fill_community_card(community_card, used_card=hole_card+community_card)
# ---> 35     unused_cards = _pick_unused_card((nb_player-1)*2, hole_card + community_card)
#      36     opponents_hole = [unused_cards[2*i:2*i+2] for i in range(nb_player-1)]
#      37     opponents_score = [HandEvaluator.eval_hand(hole, community_card) for hole in opponents_hole]
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in _pick_unused_card(card_num, used_card)
#      47     unused = [card_id for card_id in range(1, 53) if card_id not in used]
#      48     choiced = random.sample(unused, card_num)
# ---> 49     return [Card.from_id(card_id) for card_id in choiced]
#      50
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/utils/card_utils.py in <listcomp>(.0)
#      47     unused = [card_id for card_id in range(1, 53) if card_id not in used]
#      48     choiced = random.sample(unused, card_num)
# ---> 49     return [Card.from_id(card_id) for card_id in choiced]
#      50
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/card.py in from_id(cls, card_id)
#      57     while rank > 13:
#      58       suit <<= 1
# ---> 59       rank -= 13
#      60
#      61     return cls(suit, rank)
#
# KeyboardInterrupt:
