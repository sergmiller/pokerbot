# %%
from pypokerengine.api.game import setup_config, start_poker
from pypokerengine.utils.card_utils import gen_cards
from pypokerengine.players import BasePokerPlayer
from baseline_players import RandomPlayer
from bots.honest_player import HonestPlayer
from bots.honest_modified_player import HonestModifiedPlayer
from bots.bot_denis_2 import BotDenisPlayer
from bots.bot1 import KoffaPlayer
# from bots.bot_denis_4 import 
from bots.forl_condition_bot_2 import ConditionPlayer
from bots.botDenis import GloomCha
from bots.forl_condition_bot import HonestStatPlayer
from bots.fish_player import FishPlayer
from bots.fold_player import FoldPlayer
from bots.bot_denis_3 import BotDenis3Player
from copy import deepcopy
import scipy.stats as sps
import keras.backend as K
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bots.RLbot import RLPokerPlayer
from tqdm import tqdm
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# N_RANDOM_PLAYERS = 0

# config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
# # config.register_player(name="foldman", algorithm=FoldPlayer())
# config.register_player(name="honest", algorithm=HonestPlayer(200))
# config.register_player(name="honest_modified", algorithm=HonestModifiedPlayer(200))
# config.register_player(name="fishman", algorithm=FishPlayer())
# config.register_player(name="botDenis1", algorithm=GloomCha())
# config.register_player(name="botDenis2", algorithm=BotDenisPlayer())
# config.register_player(name="conditionPlayer", algorithm=ConditionPlayer())
# config.register_player(name="koffa", algorithm=KoffaPlayer())
# config.register_player(name="botDenis3", algorithm=BotDenis3Player())
# config.register_player(name="random", algorithm=RandomPlayer())

# for i in range(N_RANDOM_PLAYERS):
#     config.register_player(name="random" + str(i), algorithm=RandomPlayer())

# %%
# %%time
# from joblib import Parallel, delayed

# def f(i,config):
#     return start_poker(config, verbose=0)['players']

# def get_all_results(config, n_games=1):
#     players_stack_dict = {}
#     for player_info in config.players_info:
#         players_stack_dict[player_info['name']] = []
        
#     with Parallel(n_jobs=4) as parallel:
# #     for i in tqdm(range(n_games)):
#         data = parallel(delayed(f)(i, config) for i in range(n_games))
    
#     for i in tqdm(range(n_games)):
#         for player_info in data[i]:
#             players_stack_dict[player_info['name']].append(player_info['stack'])
            
#     return pd.DataFrame(players_stack_dict)

# res = get_all_results(config, n_games=30)

# %%
N = 100

RLBotPark = []
DefaultBotPark = [RandomPlayer(), HonestPlayer(), FishPlayer(), 
           BotDenisPlayer(), HonestModifiedPlayer(), ConditionPlayer(), 
           GloomCha(), KoffaPlayer(), HonestStatPlayer(),
          ]

rl_score = []


for i in range(N):
    in_model_file = None if i == 0 else 'model_{}.h5'.format(i)
    out_model_file = 'model_{}.h5'.format(i + 1)
    config = setup_config(max_round=50, initial_stack=1500, small_blind_amount=15)
    humans = list(np.random.choice(DefaultBotPark, replace=True, size=4 + max(0, 4 - len(RLBotPark))))
    rlbots = list(np.random.choice(RLBotPark, replace=True, size=min(4, len(RLBotPark)))) if len(RLBotPark) > 0 else []
#     print(humans, rlbots)
    players = humans + rlbots + [None]
    np.random.shuffle(players)
#     print(players)
    i = 0
    for player in players:
        i += 1
        if player is None:
            RLP =  RLPokerPlayer(
                study_mode=True,
                model_file=in_model_file,
                gammaReward=0.1,
                alphaUpdateNet=0.5,
                epsilonRandom=0.05,
                decayRandom=0.9,
                players=players,
                max_history_len=1000,
                new_model_file=out_model_file,
            )
            config.register_player(name='RL',algorithm=RLP)    
        else:
            config.register_player(name=str(player) + str(i), algorithm=player)
    info = start_poker(config, verbose=0)
    RLP.study_mode = False
    for player_info in info['players']:
        if player_info['name'] == 'RL':
            stack = player_info['stack']
            rl_score.append(stack)
            print(stack)
            break
# Out:
# fold 0
# fold 0
# fold 0
# fold 0
# fold 0
# fold 0
# fold 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-598a88856dd2> in <module>()
#      38         else:
#      39             config.register_player(name=str(player) + str(i), algorithm=player)
# ---> 40     info = start_poker(config, verbose=0)
#      41     RLP.study_mode = False
#      42     for player_info in info['players']:
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/api/game.py in start_poker(config, verbose, full_summary)
#      12     for info in config.players_info:
#      13         dealer.register_player(info["name"], info["algorithm"])
# ---> 14     result_message = dealer.start_game(config.max_round)
#      15     if full_summary:
#      16         return dealer.game_summarizer.get_summary()
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in start_game(self, max_round)
#      40       table = self.__exclude_short_of_money_players(table, ante, sb_amount)
#      41       if self.__is_game_finished(table): break
# ---> 42       table = self.play_round(round_count, sb_amount, ante, table)
#      43       table.shift_dealer_btn()
#      44     return self.__generate_game_result(max_round, table.seats)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in play_round(self, round_count, blind_amount, ante, table)
#      57         state, msgs = RoundManager.apply_action(state, action, bet_amount, bot_info=bot_info)
#      58       else:  # finish the round after publish round result
# ---> 59         self.__publish_messages(msgs)
#      60         break
#      61     return state["table"]
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in __publish_messages(self, msgs)
#     111     self.message_summarizer.summarize_messages(msgs)
#     112     self.game_summarizer.summarize_messages(msgs)
# --> 113     return self.message_handler.process_message(*msgs[-1])
#     114
#     115   def __exclude_short_of_money_players(self, table, ante, sb_amount):
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/dealer.py in process_message(self, address, msg)
#     202         return receiver.respond_to_ask(msg["message"])
#     203       elif msg["type"] == 'notification':
# --> 204         receiver.receive_notification(msg["message"])
#     205       else:
#     206         raise ValueError("Received unexpected message which type is [%s]" % msg["type"])
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/players/base.py in receive_notification(self, message)
#      70         elif msg_type == "round_result_message":
#      71             winners, hand_info, state = self.__parse_round_result_message(message)
# ---> 72             self.receive_round_result_message(winners, hand_info, state)
#      73
#      74     def __build_err_msg(self, msg):
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/RLbot.py in receive_round_result_message(self, winners, hand_info, round_state)
#     205             if len(self.history) > 10 and sps.bernoulli.rvs(p=self.alphaUpdateNet):
#     206                 ind = sps.randint.rvs(low=0, high=len(self.history) - 1)
# --> 207                 self.learn_with_states(self.history[ind], self.history[ind+1])
#     208
#     209             self.epsilonRandom *= self.decayRandom
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/RLbot.py in learn_with_states(self, state, next_state)
#     241         else:
#     242             reward = next_state['rewards'] +\
# --> 243             self.gammaReward * self.do_best_simulation(next_state['states_original'], next_state['states_vec'])
#     244
#     245         self.model.fit(x=self.turn2vec(state['states_vec'], state['moves']),
#
# /Users/sergmiller/Documents/code/python/pokerbot/bots/RLbot.py in do_best_simulation(self, next_state, next_state_vec)
#     222         best_reward = -np.inf
#     223         for action in good_actions:
# --> 224             next_next_game_state = self.emulator.apply_action(game_state, action['action'], action['amount'])
#     225             # pp = pprint.PrettyPrinter(indent=4)
#     226             # pp.pprint(next_next_game_state)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/api/emulator.py in apply_action(self, game_state, action, bet_amount)
#      60         if game_state["street"] == Const.Street.FINISHED:
#      61             game_state, events = self._start_next_round(game_state)
# ---> 62         updated_state, messages = RoundManager.apply_action(game_state, action, bet_amount)
#      63         events = [self.create_event(message[1]["message"]) for message in messages]
#      64         events = [e for e in events if e]
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in apply_action(self, original_state, action, bet_amount, bot_info)
#      33       [player.save_street_action_histories(state["street"]) for player in state["table"].seats.players]
#      34       state["street"] += 1
# ---> 35       state, street_msgs = self.__start_street(state)
#      36       return state, [update_msg] + street_msgs
#      37     else:
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __start_street(self, state)
#      77       return self.__preflop(state)
#      78     elif street == Const.Street.FLOP:
# ---> 79       return self.__flop(state)
#      80     elif street == Const.Street.TURN:
#      81       return self.__turn(state)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __flop(self, state)
#      97     for card in state["table"].deck.draw_cards(3):
#      98       state["table"].add_community_card(card)
# ---> 99     return self.__forward_street(state)
#     100
#     101   @classmethod
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __forward_street(self, state)
#     136     if table.seats.count_ask_wait_players() <= 1:
#     137       state["street"] += 1
# --> 138       state, messages = self.__start_street(state)
#     139       return state, street_start_msg + messages
#     140     else:
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __start_street(self, state)
#      79       return self.__flop(state)
#      80     elif street == Const.Street.TURN:
# ---> 81       return self.__turn(state)
#      82     elif street == Const.Street.RIVER:
#      83       return self.__river(state)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __turn(self, state)
#     102   def __turn(self, state):
#     103     state["table"].add_community_card(state["table"].deck.draw_card())
# --> 104     return self.__forward_street(state)
#     105
#     106   @classmethod
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __forward_street(self, state)
#     136     if table.seats.count_ask_wait_players() <= 1:
#     137       state["street"] += 1
# --> 138       state, messages = self.__start_street(state)
#     139       return state, street_start_msg + messages
#     140     else:
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __start_street(self, state)
#      81       return self.__turn(state)
#      82     elif street == Const.Street.RIVER:
# ---> 83       return self.__river(state)
#      84     elif street == Const.Street.SHOWDOWN:
#      85       return self.__showdown(state)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __river(self, state)
#     107   def __river(self, state):
#     108     state["table"].add_community_card(state["table"].deck.draw_card())
# --> 109     return self.__forward_street(state)
#     110
#     111   @classmethod
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __forward_street(self, state)
#     136     if table.seats.count_ask_wait_players() <= 1:
#     137       state["street"] += 1
# --> 138       state, messages = self.__start_street(state)
#     139       return state, street_start_msg + messages
#     140     else:
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __start_street(self, state)
#      83       return self.__river(state)
#      84     elif street == Const.Street.SHOWDOWN:
# ---> 85       return self.__showdown(state)
#      86     else:
#      87       raise ValueError("Street is already finished [street = %d]" % street)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/round_manager.py in __showdown(self, state)
#     111   @classmethod
#     112   def __showdown(self, state):
# --> 113     winners, hand_info, prize_map = GameEvaluator.judge(state["table"])
#     114     self.__prize_to_winners(state["table"].seats.players, prize_map)
#     115     result_message = MessageBuilder.build_round_result_message(state["round_count"], winners, hand_info, state)
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/game_evaluator.py in judge(self, table)
#      10   def judge(self, table):
#      11     winners = self.__find_winners_from(table.get_community_card(), table.seats.players)
# ---> 12     hand_info = self.__gen_hand_info_if_needed(table.seats.players, table.get_community_card())
#      13     prize_map = self.__calc_prize_distribution(table.get_community_card(), table.seats.players)
#      14     return winners, hand_info, prize_map
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/game_evaluator.py in __gen_hand_info_if_needed(self, players, community)
#      52     active_players = [player for player in players if player.is_active()]
#      53     gen_hand_info = lambda player: { "uuid": player.uuid, "hand" : HandEvaluator.gen_hand_rank_info(player.hole_card, community) }
# ---> 54     return [] if len(active_players) == 1 else [gen_hand_info(player) for player in active_players]
#      55
#      56   @classmethod
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/game_evaluator.py in <listcomp>(.0)
#      52     active_players = [player for player in players if player.is_active()]
#      53     gen_hand_info = lambda player: { "uuid": player.uuid, "hand" : HandEvaluator.gen_hand_rank_info(player.hole_card, community) }
# ---> 54     return [] if len(active_players) == 1 else [gen_hand_info(player) for player in active_players]
#      55
#      56   @classmethod
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/game_evaluator.py in <lambda>(player)
#      51   def __gen_hand_info_if_needed(self, players, community):
#      52     active_players = [player for player in players if player.is_active()]
# ---> 53     gen_hand_info = lambda player: { "uuid": player.uuid, "hand" : HandEvaluator.gen_hand_rank_info(player.hole_card, community) }
#      54     return [] if len(active_players) == 1 else [gen_hand_info(player) for player in active_players]
#      55
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/hand_evaluator.py in gen_hand_rank_info(self, hole, community)
#     101   @classmethod
#     102   def gen_hand_rank_info(self, hole, community):
# --> 103     hand = self.eval_hand(hole, community)
#     104     row_strength = self.__mask_hand_strength(hand)
#     105     strength = self.HAND_STRENGTH_MAP[row_strength]
#
# /Users/sergmiller/anaconda3/lib/python3.6/site-packages/pypokerengine/engine/hand_evaluator.py in eval_hand(self, hole, community)
#     124   def eval_hand(self, hole, community):
#     125     ranks = sorted([card.rank for card in hole])
# --> 126     hole_flg = ranks[1] << 4 | ranks[0]
#     127     hand_flg = self.__calc_hand_info_flg(hole, community) << 8
#     128     return hand_flg | hole_flg
#
# IndexError: list index out of range
